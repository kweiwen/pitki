# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal, fft, interpolate
import wavio

# %%
raw = wavio.read("chirp.wav")
left_channel = raw.data[:, 0]
right_channel = raw.data[:, 1]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0
right_channel = right_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x, magnitude, 'g--')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("chirp_loop.wav")
left_channel = raw.data[:, 0]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x, magnitude, 'g--')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("chirp_passthru.wav")
left_channel = raw.data[:, 0]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x, magnitude, 'g--')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("chirp_fft_ifft_passthru.wav")
left_channel = raw.data[:, 0]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x, magnitude, 'g--')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("front.wav")
left_channel = raw.data[:, 0][:441000]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x[20:22050], magnitude[20:22050], 'g--')
axes[1].set_xscale('log')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("front.wav")
left_channel = raw.data[:, 0][441000:441000*2]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x[20:22050], magnitude[20:22050], 'g--')
axes[1].set_xscale('log')
axes[1].grid()

plt.tight_layout()
plt.show()

# %%
raw = wavio.read("front.wav")
left_channel = raw.data[:, 0][441000*2:441000*3]

left_channel = left_channel.astype(np.float32, order='C') / 32767.0

x = np.arange(len(left_channel))
y = np.fft.fft(left_channel)
linear = abs(y / len(left_channel))
magnitude = 20 * np.log10(abs(linear))

fig, axes = plt.subplots(2, 1, figsize=(5, 5))

axes[0].plot(x, left_channel, 'b')
axes[0].grid()

axes[1].plot(x[20:22050], magnitude[20:22050], 'g--')
axes[1].set_xscale('log')
axes[1].grid()

plt.tight_layout()
plt.show()
